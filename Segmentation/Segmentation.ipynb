# %%
from PIL import Image
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from ultralytics import YOLO

# Load the image from the URL

#url = "https://www.unibz.it/assets/Images/1-University/Hero-Home/2024-12-NOI-Techpark-Campus-9907-copy__FocusFillMaxWyIwLjE4IiwiMC4yNSIsMjQ1MCwxODM4XQ.jpg"
url = "https://www.unibz.it/assets/Images/Faculty-Scitech/2024-04-05-Master-in-Environmental-Management-of-Mountain-Areas__FocusFillMaxWyIwLjAwIiwiMC4wMCIsMjQ1MCwxODM4XQ.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Load a pretrained YOLO model
model = YOLO("yolo11n-seg.pt")

# Run inference on an image
results = model(url)  # results list

# Plot the original image and the result with masks
plt.figure(figsize=(12, 6))

# Original Image
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(img)
plt.axis('off')

# Image with YOLO Segmentation
plt.subplot(1, 2, 2)
plt.title("YOLO Segmentation Result")
plt.imshow(results[0].plot()[:, :, ::-1])
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found https://www.unibz.it/assets/Images/Faculty-Scitech/2024-04-05-Master-in-Environmental-Management-of-Mountain-Areas__FocusFillMaxWyIwLjAwIiwiMC4wMCIsMjQ1MCwxODM4XQ.jpg locally at 2024-04-05-Master-in-Environmental-Management-of-Mountain-Areas__FocusFillMaxWyIwLjAwIiwiMC4wMCIsMjQ1MCwxODM4XQ.jpg
# image 1/1 /home/tb/Documents/UNIBZ_research/knime/knimevizlab/Segmentation/2024-04-05-Master-in-Environmental-Management-of-Mountain-Areas__FocusFillMaxWyIwLjAwIiwiMC4wMCIsMjQ1MCwxODM4XQ.jpg: 480x640 6 persons, 131.8ms
# Speed: 4.6ms preprocess, 131.8ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
import torch; print(torch.__version__); print(torch.cuda.is_available())
# Out:
# 2.6.0+cu124
# False

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[251, 243, 236],
#          [251, 243, 236],
#          [251, 243, 236],
#          ...,
#          [244, 209, 166],
#          [244, 210, 167],
#          [244, 210, 167]],
#
#         [[251, 243, 236],
#          [251, 243, 236],
#          [251, 243, 236],
#          ...,
#          [244, 209, 166],
#          [243, 209, 166],
#          [244, 210, 167]],
#
#         [[251, 243, 236],
#          [251, 243, 236],
#          [251, 243, 236],
#          ...,
#          [244, 209, 166],
#          [243, 209, 166],
#          [243, 209, 166]],
#
#         ...,
#
#         [[ 21,  84,  92],
#          [ 67, 122, 127],
#          [ 87, 125, 127],
#          ...,
#          [ 35,  51,  88],
#          [ 81, 109, 133],
#          [137, 174, 188]],
#
#         [[ 44, 102, 108],
#          [ 74, 116, 129],
#          [ 51,  84, 100],
#          ...,
#          [ 88, 117, 154],
#          [112, 164, 177],
#          [129, 196, 193]],
#
#         [[ 38,  98,  88],
#          [ 65, 105, 104],
#          [ 33,  74,  77],
#          ...,
#          [ 73, 114, 146],
#          [ 93, 164, 167],
#          [ 63, 160, 140]]], dtype=uint8)
#  orig_shape: (1463, 1950)
#  path: '/home/tb/Documents/UNIBZ_research/knime/knimevizlab/Segmentation/2024-04-05-Master-in-Environmental-Management-of-Mountain-Areas__FocusFillMaxWyIwLjAwIiwiMC4wMCIsMjQ1MCwxODM4XQ.jpg'
#  probs: None
#  save_dir: 'runs/segment/predict'
#  speed: {'preprocess': 4.583835601806641, 'inference': 131.77013397216797, 'postprocess': 9.784936904907227}]

# %%
boxes =results[0].boxes.xywhn
boxes
# Out:
# tensor([[0.6424, 0.5429, 0.0453, 0.1791],
#         [0.6044, 0.5487, 0.0380, 0.1675],
#         [0.7349, 0.5293, 0.0507, 0.2148],
#         [0.5185, 0.5516, 0.0548, 0.1732],
#         [0.5576, 0.5394, 0.0492, 0.1961],
#         [0.6912, 0.5462, 0.0517, 0.1735]])

# %%
boxes =results[0].masks.xyn
boxes
# Out:
# [array([[    0.62973,     0.45417],
#         [    0.62973,     0.46042],
#         [    0.63129,      0.4625],
#         [    0.63129,     0.47708],
#         [    0.62661,     0.48333],
#         [    0.62192,     0.48333],
#         [    0.62192,     0.63542],
#         [    0.63598,     0.63542],
#         [    0.63598,     0.62292],
#         [    0.63755,     0.62083],
#         [    0.63755,     0.61667],
#         [    0.63911,     0.61458],
#         [    0.64224,     0.61875],
#         [    0.64224,       0.625],
#         [     0.6438,     0.62708],
#         [     0.6438,     0.63542],
#         [    0.65318,     0.63542],
#         [    0.65318,     0.59375],
#         [    0.65161,     0.59167],
#         [    0.65161,     0.57708],
#         [    0.65318,       0.575],
#         [    0.65318,     0.56458],
#         [    0.65474,      0.5625],
#         [    0.65474,     0.55417],
#         [     0.6563,     0.55208],
#         [     0.6563,        0.55],
#         [    0.65787,     0.54792],
#         [    0.65787,     0.54167],
#         [    0.65943,     0.53958],
#         [    0.65943,     0.53333],
#         [    0.66099,     0.53125],
#         [    0.66099,     0.50833],
#         [    0.65943,     0.50625],
#         [    0.65943,     0.49792],
#         [    0.65787,     0.49583],
#         [    0.65787,     0.49167],
#         [     0.6563,     0.48958],
#         [     0.6563,      0.4875],
#         [    0.65474,     0.48542],
#         [    0.65474,     0.48333],
#         [    0.65005,     0.47708],
#         [    0.65005,       0.475],
#         [    0.64849,     0.47292],
#         [    0.64849,     0.45417]], dtype=float32),
#  array([[    0.59847,      0.4625],
#         [    0.59847,     0.46875],
#         [    0.59691,     0.47083],
#         [    0.59691,       0.475],
#         [    0.59535,     0.47708],
#         [    0.59535,     0.48333],
#         [    0.59378,     0.48542],
#         [    0.59378,     0.48958],
#         [    0.59222,     0.49167],
#         [    0.59222,     0.49375],
#         [    0.58909,     0.49792],
#         [     0.5844,     0.49792],
#         [     0.5844,       0.575],
#         [    0.58909,       0.575],
#         [    0.59222,     0.57917],
#         [    0.59222,     0.58542],
#         [    0.59378,      0.5875],
#         [    0.59378,     0.61667],
#         [    0.59535,     0.61875],
#         [    0.59535,     0.62292],
#         [    0.59691,       0.625],
#         [    0.59691,     0.62708],
#         [    0.59847,     0.62917],
#         [    0.59847,     0.63542],
#         [    0.61254,     0.63542],
#         [    0.61254,     0.61042],
#         [     0.6141,     0.60833],
#         [     0.6141,     0.59583],
#         [    0.61566,     0.59375],
#         [    0.61566,      0.5875],
#         [    0.61723,     0.58542],
#         [    0.61723,       0.575],
#         [    0.61879,     0.57292],
#         [    0.61879,     0.56042],
#         [    0.62035,     0.55833],
#         [    0.62035,     0.55625],
#         [    0.62192,     0.55417],
#         [    0.62661,     0.55417],
#         [    0.62661,     0.53333],
#         [    0.62192,     0.53333],
#         [    0.62035,     0.53125],
#         [    0.62035,     0.52917],
#         [    0.61879,     0.52708],
#         [    0.61879,     0.51875],
#         [    0.62035,     0.51667],
#         [    0.62035,     0.50625],
#         [    0.61879,     0.50417],
#         [    0.61879,     0.49375],
#         [    0.61723,     0.49167],
#         [    0.61723,     0.48542],
#         [    0.61566,     0.48333],
#         [    0.61566,     0.47917],
#         [     0.6141,     0.47708],
#         [     0.6141,     0.47292],
#         [    0.61254,     0.47083],
#         [    0.61254,      0.4625]], dtype=float32),
#  array([[    0.72195,     0.42083],
#         [    0.72195,     0.44167],
#         [    0.72351,     0.44375],
#         [    0.72351,     0.44792],
#         [    0.72195,        0.45],
#         [    0.72195,     0.45625],
#         [    0.71882,     0.46042],
#         [    0.71882,      0.4625],
#         [    0.71414,     0.46875],
#         [    0.70945,     0.46875],
#         [    0.70945,       0.525],
#         [    0.71414,       0.525],
#         [     0.7157,     0.52708],
#         [     0.7157,     0.52917],
#         [    0.71726,     0.53125],
#         [    0.71726,     0.54792],
#         [    0.71882,        0.55],
#         [    0.71882,     0.55833],
#         [    0.72039,     0.56042],
#         [    0.72039,     0.56458],
#         [    0.72195,     0.56667],
#         [    0.72195,     0.57083],
#         [    0.72351,     0.57292],
#         [    0.72351,     0.58125],
#         [    0.72508,     0.58333],
#         [    0.72508,     0.58958],
#         [    0.72664,     0.59167],
#         [    0.72664,         0.6],
#         [     0.7282,     0.60208],
#         [     0.7282,     0.61042],
#         [    0.72977,      0.6125],
#         [    0.72977,     0.61875],
#         [    0.73133,     0.62083],
#         [    0.73133,       0.625],
#         [    0.73289,     0.62708],
#         [    0.73289,     0.63125],
#         [    0.73446,     0.63333],
#         [    0.73602,     0.63333],
#         [    0.73758,     0.63542],
#         [    0.74852,     0.63542],
#         [    0.75009,     0.63333],
#         [    0.75165,     0.63333],
#         [    0.75321,     0.63125],
#         [    0.75321,     0.62708],
#         [    0.75477,       0.625],
#         [    0.75477,     0.59375],
#         [    0.75321,     0.59167],
#         [    0.75321,     0.58333],
#         [    0.75165,     0.58125],
#         [    0.75165,     0.54792],
#         [    0.75321,     0.54583],
#         [    0.75321,     0.53958],
#         [    0.75477,      0.5375],
#         [    0.75477,     0.53125],
#         [    0.75634,     0.52917],
#         [    0.75634,      0.5125],
#         [     0.7579,     0.51042],
#         [     0.7579,     0.50625],
#         [    0.75946,     0.50417],
#         [    0.76415,     0.50417],
#         [    0.76415,     0.47708],
#         [     0.7579,     0.47708],
#         [    0.75634,       0.475],
#         [    0.75634,     0.47292],
#         [    0.75477,     0.47083],
#         [    0.75477,     0.46875],
#         [    0.74383,     0.45417],
#         [    0.74383,     0.45208],
#         [    0.74227,        0.45],
#         [    0.74227,     0.42083]], dtype=float32),
#  array([[    0.50938,      0.4625],
#         [    0.50938,     0.47083],
#         [    0.50782,     0.47292],
#         [    0.50782,       0.475],
#         [    0.50625,     0.47708],
#         [    0.50625,     0.48542],
#         [    0.50469,      0.4875],
#         [    0.50469,     0.49375],
#         [    0.50313,     0.49583],
#         [    0.50313,     0.49792],
#         [        0.5,     0.50208],
#         [        0.5,     0.50625],
#         [    0.49531,      0.5125],
#         [    0.49062,      0.5125],
#         [    0.49062,     0.55833],
#         [    0.49531,     0.55833],
#         [    0.49844,      0.5625],
#         [    0.49844,     0.59167],
#         [    0.49687,     0.59375],
#         [    0.49687,     0.59583],
#         [    0.49531,     0.59792],
#         [    0.49062,     0.59792],
#         [    0.49062,     0.63333],
#         [    0.50313,     0.63333],
#         [    0.50469,     0.63125],
#         [    0.50469,     0.62708],
#         [    0.50625,       0.625],
#         [    0.50625,     0.61042],
#         [    0.50782,     0.60833],
#         [    0.50782,     0.60417],
#         [    0.50938,     0.60208],
#         [    0.50938,         0.6],
#         [    0.51094,     0.59792],
#         [    0.51094,     0.59167],
#         [     0.5125,     0.58958],
#         [     0.5125,     0.58333],
#         [    0.51563,     0.57917],
#         [    0.52032,     0.57917],
#         [    0.52188,     0.58125],
#         [    0.52188,     0.58333],
#         [    0.52345,     0.58542],
#         [    0.52345,     0.59167],
#         [    0.52501,     0.59375],
#         [    0.52501,     0.60208],
#         [    0.52657,     0.60417],
#         [    0.52657,     0.60833],
#         [    0.52813,     0.61042],
#         [    0.52813,      0.6125],
#         [     0.5297,     0.61458],
#         [     0.5297,     0.61875],
#         [    0.53126,     0.62083],
#         [    0.53126,       0.625],
#         [    0.53282,     0.62708],
#         [    0.53282,     0.62917],
#         [    0.53439,     0.63125],
#         [    0.53908,     0.63125],
#         [     0.5422,     0.62708],
#         [    0.54064,       0.625],
#         [    0.54064,     0.61042],
#         [    0.53908,     0.60833],
#         [    0.53908,     0.60208],
#         [    0.53751,         0.6],
#         [    0.53751,     0.57917],
#         [    0.53595,     0.57708],
#         [    0.53595,     0.54583],
#         [    0.53439,     0.54375],
#         [    0.53439,       0.525],
#         [    0.53282,     0.52292],
#         [    0.53282,     0.51667],
#         [    0.53126,     0.51458],
#         [    0.53126,     0.51042],
#         [     0.5297,     0.50833],
#         [     0.5297,     0.49792],
#         [    0.52813,     0.49583],
#         [    0.52813,     0.49375],
#         [     0.5297,     0.49167],
#         [     0.5297,      0.4625]], dtype=float32),
#  array([[    0.54689,      0.4375],
#         [    0.54689,     0.44792],
#         [    0.54533,        0.45],
#         [    0.54533,     0.45417],
#         [    0.54376,     0.45625],
#         [    0.54376,     0.46042],
#         [    0.53908,     0.46667],
#         [    0.53439,     0.46667],
#         [    0.53439,        0.55],
#         [    0.53908,        0.55],
#         [    0.54064,     0.55208],
#         [    0.54064,     0.55625],
#         [     0.5422,     0.55833],
#         [     0.5422,     0.57292],
#         [    0.54376,       0.575],
#         [    0.54376,     0.62292],
#         [     0.5422,       0.625],
#         [     0.5422,     0.62917],
#         [    0.54376,     0.62917],
#         [    0.54533,     0.63125],
#         [    0.54689,     0.63125],
#         [    0.54845,     0.63333],
#         [    0.55002,     0.63333],
#         [    0.55158,     0.63542],
#         [    0.55314,     0.63542],
#         [    0.55471,      0.6375],
#         [    0.55471,     0.64375],
#         [    0.56565,     0.64375],
#         [    0.56565,     0.63542],
#         [    0.56721,     0.63333],
#         [    0.56721,     0.63125],
#         [    0.56877,     0.62917],
#         [    0.56877,     0.61042],
#         [    0.57034,     0.60833],
#         [    0.57034,     0.57083],
#         [     0.5719,     0.56875],
#         [     0.5719,     0.55625],
#         [    0.57346,     0.55417],
#         [    0.57346,     0.54583],
#         [    0.57503,     0.54375],
#         [    0.57503,     0.54167],
#         [    0.57815,      0.5375],
#         [    0.57815,     0.53125],
#         [    0.57971,     0.52917],
#         [    0.57971,     0.49583],
#         [    0.57815,     0.49375],
#         [    0.57815,     0.49167],
#         [    0.57659,     0.48958],
#         [    0.57659,      0.4875],
#         [    0.57503,     0.48542],
#         [    0.57503,     0.48333],
#         [    0.57346,     0.48125],
#         [    0.57346,     0.47917],
#         [     0.5719,     0.47708],
#         [     0.5719,       0.475],
#         [    0.56877,     0.47083],
#         [    0.56877,     0.46458],
#         [    0.56721,      0.4625],
#         [    0.56721,     0.44792],
#         [    0.56565,     0.44583],
#         [    0.56565,      0.4375]], dtype=float32),
#  array([[    0.68287,      0.4625],
#         [    0.68287,      0.4875],
#         [    0.67662,     0.49583],
#         [    0.67662,     0.49792],
#         [    0.67506,         0.5],
#         [    0.67506,     0.50208],
#         [    0.67037,     0.50833],
#         [    0.66568,     0.50833],
#         [    0.66568,     0.53333],
#         [    0.67193,     0.53333],
#         [     0.6735,     0.53542],
#         [     0.6735,     0.54792],
#         [    0.67506,        0.55],
#         [    0.67506,     0.55625],
#         [    0.67662,     0.55833],
#         [    0.67662,     0.57292],
#         [    0.67819,       0.575],
#         [    0.67819,         0.6],
#         [    0.67975,     0.60208],
#         [    0.67975,     0.61667],
#         [    0.68131,     0.61875],
#         [    0.68131,     0.62708],
#         [    0.68287,     0.62917],
#         [    0.68287,     0.63542],
#         [    0.70945,     0.63542],
#         [    0.70945,     0.60417],
#         [    0.71101,     0.60208],
#         [    0.71101,     0.59583],
#         [    0.70945,     0.59375],
#         [    0.70945,     0.55625],
#         [    0.71101,     0.55417],
#         [    0.71101,        0.55],
#         [    0.71257,     0.54792],
#         [    0.71257,     0.54375],
#         [    0.71414,     0.54167],
#         [    0.71414,     0.53958],
#         [     0.7157,      0.5375],
#         [    0.72039,      0.5375],
#         [    0.72039,     0.53125],
#         [     0.7157,     0.53125],
#         [    0.71414,     0.52917],
#         [    0.71414,     0.52708],
#         [    0.71257,       0.525],
#         [    0.71257,     0.52292],
#         [    0.71101,     0.52083],
#         [    0.71101,     0.51875],
#         [    0.70945,     0.51667],
#         [    0.70945,     0.50833],
#         [    0.70788,     0.50625],
#         [    0.70788,     0.49375],
#         [    0.70632,     0.49167],
#         [    0.70632,     0.48958],
#         [    0.70476,      0.4875],
#         [    0.70476,     0.48125],
#         [    0.70319,     0.47917],
#         [    0.70319,     0.47083],
#         [    0.70163,     0.46875],
#         [    0.70163,      0.4625]], dtype=float32)]
